# %% [markdown]
# # Módulo 01: Programación
# # Práctica 1: Python
# # Sesión 2: Python Clases y objetos.

# %%
import sys
print("Python version")
print (sys.version)
print("Version info.")
print (sys.version_info)
# Out:
# Python version
# 3.7.10 (default, Feb 20 2021, 21:17:23)
# [GCC 7.5.0]
# Version info.
# sys.version_info(major=3, minor=7, micro=10, releaselevel='final', serial=0)

# %% [markdown]
# **1) Adivina número. OOP.**
#
# Resuelve el ejercicio 1 utilizando clases.
#
# ![ej6.png](data:image/png;base64,...)

# %% [markdown]
# **2) Adivina número con intentos finitos. OOP.**
#
# Resuelve el ejercicio 2 utilizando clases.
#
#
# ![ej7.png](data:image/png;base64,...)

# %% [markdown]
# **3) Adivina palabra. OOP.**
#
# Resuelve el ejercicio 3 utilizando clases y herencia.
#
#
# ![ej8.png](data:image/png;base64,...)

# %% [markdown]
# **4) Adivina frase. OOP.**
#
# Resuelve el ejercicio 4 utilizando clases y herencia.
#
#
# ![ej9.png](data:image/png;base64,...)

# %% [markdown]
# **5) Adivina frase + puntos / comodines. OOP.**
#
# Resuelve el ejercicio 5 utilizando clases y herencia.

# %% [markdown]
# ## Evaluación
# Ejercicio 1 -> 2.5 puntos
#
# Ejercicio 2 -> 2.5 puntos
#
# Ejercicio 3 -> 2.5 puntos
#
# Ejercicio 4 -> 2.5 puntos
#
# Ejercicio 5 -> extra 1 punto
